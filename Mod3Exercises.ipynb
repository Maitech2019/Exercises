# %% [markdown]
# # Module 3 Exercises - Data Manipulation

# %% [markdown]
# ### Exercise 1:
#
# From the datasets folder, load in the "dupedata.csv" file as a dataframe. Drop the duplicates from the dataframe, keeping the first value (save the resulting dataframe to a new variable).

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datasets/dupedata.csv")
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df.count()
# Out:
# fname       2038
# lname       2038
# gender      2038
# age         2038
# exercise    2038
# hours       2038
# grade       2038
# address     2038
# dtype: int64

# %%
df2 = df.drop_duplicates()

# %%
df2.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df2.count()
# Out:
# fname       2000
# lname       2000
# gender      2000
# age         2000
# exercise    2000
# hours       2000
# grade       2000
# address     2000
# dtype: int64

# %%
#keeping the last value
df3 = df.drop_duplicates(['fname'], keep='last')

# %%
df3.count()
# Out:
# fname       958
# lname       958
# gender      958
# age         958
# exercise    958
# hours       958
# grade       958
# address     958
# dtype: int64

# %% [markdown]
# ### Exercise 2:
#
# Using the dataframe in the previous exercise, select all the rows where students received a grade lower than 60 (they need a teacher conference on how to improve for the next test).

# %%
#finds rows where the grade is less than or equal to 100
df2.loc[df2['grade'] <= 60]
# Out:
#            fname       lname  gender  age  exercise  hours  grade  \
# 340        Abbot        Hall    male   16         4      3   58.9
# 410        Linda     Baldwin  female   16         5      2   59.0
# 556        Lacey      Nieves  female   18         1      2   57.9
# 664        Alika       Poole  female   19         2     16   32.0
# 672       Ciaran         Gay    male   19         4      3   59.3
# 700       Steven     Sherman    male   18         1      2   60.0
# 972       Keegan   Rasmussen    male   19         4      3   43.0
# 1068      Isaiah  Harrington    male   17         1      4   58.9
# 1207       Selma       Stout  female   19         2      3   59.4
# 1237       Willa       Byers  female   14         2      4   59.2
# 1494       Jenna      Wagner  female   16         1      3   56.3
# 1876        Levi     Coleman    male   19         3      3   55.9
# 1888  Fitzgerald        Goff    male   18         1      4   59.8
# 1916        Gail      Mcneil  female   17         2      3   56.1
# 1930     Xanthus      Mcneil    male   16         3      4   59.8
#
#                                              address
# 340             84 Rock Creek Lane, Durham, NC 27703
# 410       970 SW. Second Ave., Cedar Falls, IA 50613
# 556   38 West Brickyard Avenue, Roslindale, MA 02131
# 664      9282 Purple Finch Lane, Lexington, NC 27292
# 672              157 Bridge Street, Corona, NY 11368
# 700      8029 Depot Street, Port Charlotte, FL 33952
# 972    876 East Pilgrim Street, Chelmsford, MA 01824
# 1068         47 Mill Pond St., Haines City, FL 33844
# 1207                 5 Pierce St., Chester, PA 19013
# 1237           9466 Wayne Lane, Torrington, CT 06790
# 1494     8829 Shore Dr., Hopewell Junction, NY 12533
# 1876       9453 Laurel Street, Jersey City, NJ 07302
# 1888         3 West Shipley Rd., Langhorne, PA 19047
# 1916             8409A Spruce St., Fishers, IN 46037
# 1930       226 Redwood Lane, Boynton Beach, FL 33435

# %% [markdown]
# ### Exercise 3:
#
# Using the dataframe from Exercise 1, select all the rows where a student received a grade of 100 and change their grade to 103 (extra credit!).

# %%
#finds rows where the grade is less than or equal to 100
df2.loc[df2['grade'] == 100, 'grade'] = 103

# %%
df2.head(10)
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10  103.0
# 1   Kadeem  Morrison    male   18         4      4  103.0
# 2     Nash    Powell    male   18         5      9  103.0
# 3  Noelani    Wagner  female   14         2      7  103.0
# 4  Noelani    Cherry  female   18         4     15  103.0
# 5     Neil   Whitley    male   16         5     16  103.0
# 6    Nelle    Golden  female   17         1      9  103.0
# 7  Armando   Hoffman    male   17         5     18  103.0
# 8  Illiana     Rojas  female   15         5      9  103.0
# 9     Neil    Wooten    male   15         3     15  103.0
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035
# 5  40 Washington Ave., Bloomfield, NJ 07003
# 6     9768 Hanover Dr., Meadville, PA 16335
# 7     360 Manor Drive, Northville, MI 48167
# 8  9425 Studebaker Dr., Thibodaux, LA 70301
# 9   400 Bridge Court, Soddy Daisy, TN 37379

# %% [markdown]
# ### Exercise 4:
#
# Load in the "travel_times.csv" file as a dataframe. Drop the "Comments" column. Then remove rows from the dataframe that have missing values and assign the resulting dataframe as a new variable.

# %%
df = pd.read_csv("travel_times.csv.xls")
df.head()
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# 0            84.8         NaN       39.3        36.3         No      NaN
# 1            88.9         NaN       37.9        34.9         No      NaN
# 2            85.8         NaN       37.5        35.9         No      NaN
# 3            82.9         NaN       39.8        35.6         No      NaN
# 4            88.1         NaN       36.8        34.8         No      NaN

# %%
#drop column & assigned a ned dataframe name
df1 = df.drop('Comments', axis=1)
df1.head()
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All
# 0            84.8         NaN       39.3        36.3         No
# 1            88.9         NaN       37.9        34.9         No
# 2            85.8         NaN       37.5        35.9         No
# 3            82.9         NaN       39.8        35.6         No
# 4            88.1         NaN       36.8        34.8         No

# %%
#drop Missing Value
df1.dropna()

df1.head()
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All
# 0            84.8         NaN       39.3        36.3         No
# 1            88.9         NaN       37.9        34.9         No
# 2            85.8         NaN       37.5        35.9         No
# 3            82.9         NaN       39.8        35.6         No
# 4            88.1         NaN       36.8        34.8         No

# %%
#df.fillna()

# %% [markdown]
# ### Exercise 5:
#
# Using the dataframe from the exercise above (w/ no missing values), create bins that will categorize the AvgSpeed column as "slow" or "fast", and make a new column called "Speed" to hold those new values. Values less than 75 are "slow" and everything above is "fast".

# %%
#average speed "slow = <75", "fast = >75"
binslist = [0, 75, 160]

speedlist = ['slow', 'fast']

df1['Speed'] = pd.cut(df1['AvgSpeed'], binslist, labels=speedlist)

# %%
df1.head()
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Speed
# 0            84.8         NaN       39.3        36.3         No  fast
# 1            88.9         NaN       37.9        34.9         No  fast
# 2            85.8         NaN       37.5        35.9         No  fast
# 3            82.9         NaN       39.8        35.6         No  slow
# 4            88.1         NaN       36.8        34.8         No  fast

# %% [markdown]
# ### Exercise 6:
#
# Using the dataframe in the previous exercise, make a new column called "Police" which is equal to all the values being "no" (they were never stopped by police for speeding while traveling).

# %%
df1['Police'] = 'no'
df1.head()
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Speed Police
# 0            84.8         NaN       39.3        36.3         No  fast     no
# 1            88.9         NaN       37.9        34.9         No  fast     no
# 2            85.8         NaN       37.5        35.9         No  fast     no
# 3            82.9         NaN       39.8        35.6         No  slow     no
# 4            88.1         NaN       36.8        34.8         No  fast     no

# %% [markdown]
# ### Exercise 7:
#
# Using the dataframe from the previous exercise, pick a method (Standard Deviation or Interquartile Range) and remove the outliers from the "FuelEconomy" column.

# %%
df1.head()
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Speed Police
# 0            84.8         NaN       39.3        36.3         No  fast     no
# 1            88.9         NaN       37.9        34.9         No  fast     no
# 2            85.8         NaN       37.5        35.9         No  fast     no
# 3            82.9         NaN       39.8        35.6         No  slow     no
# 4            88.1         NaN       36.8        34.8         No  fast     no

# %%
df1.dtypes
# Out:
# Date                object
# StartTime           object
# DayOfWeek           object
# GoingTo             object
# Distance           float64
# MaxSpeed           float64
# AvgSpeed           float64
# AvgMovingSpeed     float64
# FuelEconomy         object
# TotalTime          float64
# MovingTime         float64
# Take407All          object
# Speed             category
# Police              object
# dtype: object

# %%
#Standard Deviation Method

meangrade = df['FuelEconomy'].mean()
stdgrade = df['FuelEconomy'].std()
toprange = meangrade + stdgrade * 1.96
botrange = meangrade - stdgrade * 1.96

copydf = df.copy() #to not mess up the original df
copydf = copydf.drop(copydf[copydf['FuelEconomy'] > toprange].index)
copydf = copydf.drop(copydf[copydf['FuelEconomy'] < botrange].index)

copydf.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     354     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 355     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     356
#
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-746aec3a627c> in <module>
#       1 #Standard Deviation Method
#       2
# ----> 3 meangrade = df['FuelEconomy'].mean()
#       4 stdgrade = df['FuelEconomy'].std()
#       5 toprange = meangrade + stdgrade * 1.96
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    9611                                       skipna=skipna)
#    9612         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9613                             numeric_only=numeric_only)
#    9614
#    9615     return set_function_name(stat_func, name, cls)
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3219                                           'numeric_only.'.format(name))
#    3220             with np.errstate(all='ignore'):
# -> 3221                 return op(delegate, skipna=skipna, **kwds)
#    3222
#    3223         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      75             try:
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#      79                 # we want to transform an object array
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     129             except Exception:
#     130                 try:
# --> 131                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     132                 except ValueError as e:
#     133                     # we want to transform an object array
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     353         dtype_count = dtype
#     354     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 355     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     356
#     357     if axis is not None and getattr(the_sum, 'ndim', False):
#
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#      38 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#Interquartile Range Method

q1 = df['FuelEconomy'].quantile(.25)
q3 = df['FuelEconomy'].quantile(.75)
iqr = q3-q1
toprange = q3 + iqr * 1.5
botrange = q1 - iqr * 1.5

newdf = df.copy()
newdf = newdf.drop(newdf[newdf['FuelEconomy'] > toprange].index)
newdf = newdf.drop(newdf[newdf['FuelEconomy'] < botrange].index)

newdf.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-680a49e0b736> in <module>
#       1 #Interquartile Range Method
#       2
# ----> 3 q1 = df['FuelEconomy'].quantile(.25)
#       4 q3 = df['FuelEconomy'].quantile(.75)
#       5 iqr = q3-q1
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in quantile(self, q, interpolation)
#    1876         self._check_percentile(q)
#    1877
# -> 1878         result = self._data.quantile(qs=q, interpolation=interpolation)
#    1879
#    1880         if is_list_like(q):
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in quantile(self, **kwargs)
#    3688
#    3689     def quantile(self, **kwargs):
# -> 3690         return self.reduction('quantile', **kwargs)
#    3691
#    3692     def setitem(self, **kwargs):
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in reduction(self, f, axis, consolidate, transposed, **kwargs)
#    3617         for b in self.blocks:
#    3618             kwargs['mgr'] = self
# -> 3619             axe, block = getattr(b, f)(axis=axis, **kwargs)
#    3620
#    3621             axes.append(axe)
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in quantile(self, qs, interpolation, axis, mgr)
#    1681                     result = np.array([self._na_value] * len(self))
#    1682             else:
# -> 1683                 result = _nanpercentile(values, qs * 100, axis=axis, **kw)
#    1684
#    1685         ndim = getattr(result, 'ndim', None) or 0
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in _nanpercentile(values, q, axis, **kw)
#    1624             if not is_scalar(mask) and mask.any():
#    1625                 if self.ndim == 1:
# -> 1626                     return _nanpercentile1D(values, mask, q, **kw)
#    1627                 else:
#    1628                     # for nonconsolidatable blocks mask is 1D, but values 2D
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in _nanpercentile1D(values, mask, q, **kw)
#    1617                                     dtype=values.dtype)
#    1618
# -> 1619             return np.percentile(values, q, **kw)
#    1620
#    1621         def _nanpercentile(values, q, axis, **kw):
#
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3538         raise ValueError("Percentiles must be in the range [0, 100]")
#    3539     return _quantile_unchecked(
# -> 3540         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3541
#    3542
#
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3650     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3651                     overwrite_input=overwrite_input,
# -> 3652                     interpolation=interpolation)
#    3653     if keepdims:
#    3654         return r.reshape(q.shape + k)
#
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3248         keepdim = (1,) * a.ndim
#    3249
# -> 3250     r = func(a, **kwargs)
#    3251     return r, keepdim
#    3252
#
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _quantile_ureduce_func(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3765             n = np.isnan(ap[-1:, ...])
#    3766
# -> 3767         x1 = take(ap, indices_below, axis=axis) * weights_below
#    3768         x2 = take(ap, indices_above, axis=axis) * weights_above
#    3769
#
# TypeError: can't multiply sequence by non-int of type 'float'
